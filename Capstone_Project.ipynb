# %% [markdown]
# # <font color='#4682B4'>Capstone Project</font>
# ## <font color='#4682B4'>“Digital Wellness: Exploring Screen Time, Sleep, and Stress through Data Analysis”</font>
# <hr style="height:2px;border:none;color:#4682B4;background-color:#4682B4;" />
#
# ### <font color='#4682B4'>Project Objective</font>
# This project aims to explore how screen time, sleep habits, and stress levels are connected by carrying out a full exploratory data analysis (EDA) in Python. The work will involve:
#
# * Loading the dataset and getting an initial sense of its structure.
# * Cleaning and preparing the data by fixing missing values, correcting formats, and creating useful new columns.
# * Running descriptive and exploratory analysis to spot patterns, correlations, and trends.
# * Creating clear visualizations with Python libraries like Matplotlib, Seaborn, and Plotly to make the findings easy to understand.
# * Summarizing the key insights with straightforward explanations, highlighting important relationships and observations.

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### <font color='#4682B4'>1. Dataset Loading</font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />

# %%
data = pd.read_csv("Smartphone Usage  Dataset.csv")

# %% [markdown]
# ### <font color='#4682B4'> 2. Initial Overview</font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />

# %%
#2.1 Number of rows and columns in the dataset
rows, columns= data.shape
print(f"The dataset contains {rows} rows and {columns} columns.\n")
# Out:
# The dataset contains 50024 rows and 13 columns.

# %%
#2.2 Column names
print(data.columns)
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Device_Type',
#        'Daily_Phone_Hours', 'Social_Media_Hours', 'Work_Productivity_Score',
#        'Sleep_Hours', 'Stress_Level', 'App_Usage_Count',
#        'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours'],
#       dtype='object')

# %%
#2.3 Data types of each column 
print("\nData types:")
print (data.dtypes)
# Out:
# Data types:
# User_ID                       object
# Age                            int64
# Gender                        object
# Occupation                    object
# Device_Type                   object
# Daily_Phone_Hours            float64
# Social_Media_Hours           float64
# Work_Productivity_Score        int64
# Sleep_Hours                  float64
# Stress_Level                 float64
# App_Usage_Count                int64
# Caffeine_Intake_Cups           int64
# Weekend_Screen_Time_Hours    float64
# dtype: object

# %%
#2.4 Initial observations
data.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8           NaN
# 1                 1.5                        5          6.4           1.0
# 2                 5.7                        5          9.0           4.0
# 3                 2.5                        2          5.7           3.0
# 4                 1.3                        4          5.7           3.0
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours
# ...

# %%
data.tail()
# Out:
#       User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 50019  U49863   40   Other         Student     Android               10.9
# 50020  U49864   20  Female    Professional     Android                2.3
# 50021  U49865   20    Male         Student         iOS               10.2
# 50022  U49866   20    Male  Business Owner         iOS               10.0
# 50023  U49867   37   Other      Freelancer         iOS                1.4
#
#        Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 50019                 4.8                        9          6.6           1.0
# 50020                 1.0                        6          8.7           2.0
# 50021                 7.2                        7          4.4           6.0
# 50022                 3.5                        7          6.3           8.0
# 50023                 2.7                        3          7.8           5.0
#
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50024 entries, 0 to 50023
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   User_ID                    50024 non-null  object
#  1   Age                        50024 non-null  int64
#  2   Gender                     50024 non-null  object
#  3   Occupation                 50024 non-null  object
#  4   Device_Type                50024 non-null  object
#  5   Daily_Phone_Hours          50024 non-null  float64
#  6   Social_Media_Hours         50024 non-null  float64
#  7   Work_Productivity_Score    50024 non-null  int64
#  8   Sleep_Hours                49997 non-null  float64
#  9   Stress_Level               49998 non-null  float64
#  10  App_Usage_Count            50024 non-null  int64
#  11  Caffeine_Intake_Cups       50024 non-null  int64
#  12  Weekend_Screen_Time_Hours  50024 non-null  float64
# ...

# %%
print("\nSummery statistics:")
data.describe()
# Out:
# Summery statistics:
#                 Age  Daily_Phone_Hours  Social_Media_Hours  \
# count  50024.000000       50024.000000        50024.000000
# mean      39.034124           6.509340            4.267454
# std       12.415810           3.171067            2.164829
# min       18.000000           1.000000            0.500000
# 25%       28.000000           3.800000            2.400000
# 50%       39.000000           6.500000            4.300000
# 75%       50.000000           9.200000            6.100000
# max       60.000000          12.000000            8.000000
#
#        Work_Productivity_Score   Sleep_Hours  Stress_Level  App_Usage_Count  \
# count             50024.000000  49997.000000  49998.000000     50024.000000
# mean                  5.503718      6.497818      5.504740        32.439469
# std                   2.874736      1.449596      2.871066        16.121193
# min                   1.000000      4.000000      1.000000         5.000000
# ...

# %% [markdown]
# ### <font color='#4682B4'> Summery of Initial Overview (Pre-Cleaning) </font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />
#
# - The dataset contains **50024 rows × 13 columns**, covering variables such as screen time, sleep hours, stress levels, productivity, caffeine intake, weekend screen time, and demographics.
# - **Data types** are consistent: numeric for continuous measures, categorical for usage/stress groups, gender, and occupation.
# - **Missing values check:** Some columns show, which will be handled in the data cleaning step.
# - **Head/Tail inspection:** Confirms the dataset is structured correctly and values fall within expected ranges.
# - **Describe():** Early stats highlight variation in screen time and sleep, with stress and productivity showing potential links.
# - **Info():** Confirms column types and non-null counts, ensuring readiness for cleaning and deeper analysis.
#
# These initial checks validate the dataset structure and highlight areas that need attention before proceeding to cleaning and detailed EDA.

# %% [markdown]
# ### <font color='#4682B4'> 3.  Data Pre-processing </font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />

# %% [markdown]
# #### <font color='#4682B4'> 3.1.  Handling missing values </font>

# %%
#Checking missing values 

print(data.isnull().sum())
# Out:
# User_ID                       0
# Age                           0
# Gender                        0
# Occupation                    0
# Device_Type                   0
# Daily_Phone_Hours             0
# Social_Media_Hours            0
# Work_Productivity_Score       0
# Sleep_Hours                  27
# Stress_Level                 26
# App_Usage_Count               0
# Caffeine_Intake_Cups          0
# Weekend_Screen_Time_Hours     0
# dtype: int64

# %%
#Handling missing values using median 

data['Sleep_Hours']= data['Sleep_Hours'].fillna(data['Sleep_Hours'].median())

data['Stress_Level']= data['Stress_Level'].fillna(data['Stress_Level'].median())

# %%
print(data.isnull().sum())
# Out:
# User_ID                      0
# Age                          0
# Gender                       0
# Occupation                   0
# Device_Type                  0
# Daily_Phone_Hours            0
# Social_Media_Hours           0
# Work_Productivity_Score      0
# Sleep_Hours                  0
# Stress_Level                 0
# App_Usage_Count              0
# Caffeine_Intake_Cups         0
# Weekend_Screen_Time_Hours    0
# dtype: int64

# %% [markdown]
# #### <font color='#4682B4'> 3.2.  Removing duplicates </font>

# %%
#checking for duplicate rows

duplicates_count= data.duplicated().sum()
print("Number of duplicate rows:",duplicates_count)
# Out:
# Number of duplicate rows: 24

# %%
#Removing duplicate rows

data=data.drop_duplicates()

# %%
duplicates_count= data.duplicated().sum()
print("Number of duplicate rows:",duplicates_count)
# Out:
# Number of duplicate rows: 0

# %% [markdown]
# #### <font color='#4682B4'> 3.3.  Correcting data types </font>

# %%
#Gender, Occupation, and Device Type are categorical fields.  
#Converting them from object to category type to improve efficiency and analysis.

categorical_cols = ['Gender', 'Occupation', 'Device_Type']
for col in categorical_cols:
    data[col] = data[col].astype('category')

# %%
print("\nData types:")
print (data.dtypes)
# Out:
# Data types:
# User_ID                        object
# Age                             int64
# Gender                       category
# Occupation                   category
# Device_Type                  category
# Daily_Phone_Hours             float64
# Social_Media_Hours            float64
# Work_Productivity_Score         int64
# Sleep_Hours                   float64
# Stress_Level                  float64
# App_Usage_Count                 int64
# Caffeine_Intake_Cups            int64
# Weekend_Screen_Time_Hours     float64
# dtype: object

# %% [markdown]
# #### <font color='#4682B4'> 3.4.  Creating derived columns  </font>

# %%
# A. Total daily screen time
data['Total_Screen_Time'] = data['Daily_Phone_Hours'] + data['Social_Media_Hours']

# %%
# B. Usage Categorization
def get_usage(hours):
    if hours <= 4: return 'Light'
    elif hours <= 8: return 'Moderate'
    else: return 'Heavy'
data['Usage_Category'] = data['Total_Screen_Time'].apply(get_usage)

# %%
# C. Stress Categorization
def get_stress(level):
    if level <= 3: return 'Low'
    elif level <= 7: return 'Moderate'
    else: return 'High'
data['Stress_Category'] = data['Stress_Level'].apply(get_stress)

# %%
# D. Sleep Efficiency (%)
data['Sleep_Efficiency'] = (data['Sleep_Hours'] / 24) * 100

# %%
# E. Digital Balance Score
data['Digital_Balance_Score'] = (data['Sleep_Hours'] + data['Work_Productivity_Score']) / (data['Total_Screen_Time'] + 1)

# %%
print(data.columns)
# Out:
# Index(['User_ID', 'Age', 'Gender', 'Occupation', 'Device_Type',
#        'Daily_Phone_Hours', 'Social_Media_Hours', 'Work_Productivity_Score',
#        'Sleep_Hours', 'Stress_Level', 'App_Usage_Count',
#        'Caffeine_Intake_Cups', 'Weekend_Screen_Time_Hours',
#        'Total_Screen_Time', 'Usage_Category', 'Stress_Category',
#        'Sleep_Efficiency', 'Digital_Balance_Score'],
#       dtype='object')

# %% [markdown]
# #### <font color='#4682B4'> 3.5.  Filtering or aggregating data  </font>

# %%
# 1. Filtering (Removing Outliers & Errors) 
# ensuring sleep is realistic (0-18 hours) and screen time is not negative.
data_cleaned = data[(data['Sleep_Hours'] >= 0) & (data['Sleep_Hours'] <= 18)].copy()
data_cleaned = data_cleaned[data_cleaned['Total_Screen_Time'] >= 0]

# %%
# 2. Final Aggregation (Data Quality Check) 
quality_check = data_cleaned.groupby('Usage_Category').agg({
    'User_ID': 'count',
    'Total_Screen_Time': ['min', 'max', 'mean'],
    'Digital_Balance_Score': 'mean'
}).round(2)

# %% [markdown]
# ### <font color='#4682B4'> Final Data Preview </font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />
#
# After completing all preprocessing steps (cleaning, type corrections, derived columns, filtering, aggregation), here’s the updated dataset:

# %%
data.head()
# Out:
#   User_ID  Age  Gender      Occupation Device_Type  Daily_Phone_Hours  \
# 0      U1   58    Male    Professional     Android                1.3
# 1      U2   25    Male    Professional     Android                1.2
# 2      U3   19    Male         Student         iOS                5.3
# 3      U4   35  Female  Business Owner         iOS                5.8
# 4      U5   33    Male      Freelancer     Android                7.9
#
#    Social_Media_Hours  Work_Productivity_Score  Sleep_Hours  Stress_Level  \
# 0                 6.7                        6          8.8           6.0
# 1                 1.5                        5          6.4           1.0
# 2                 5.7                        5          9.0           4.0
# 3                 2.5                        2          5.7           3.0
# 4                 1.3                        4          5.7           3.0
#
#    App_Usage_Count  Caffeine_Intake_Cups  Weekend_Screen_Time_Hours  \
# ...

# %%
rows, columns= data.shape
print(f"The dataset contains {rows} rows and {columns} columns.\n")
# Out:
# The dataset contains 50000 rows and 18 columns.

# %% [markdown]
# ### <font color='#4682B4'> Summary of Data Pre-processing </font>
# <hr style="height:1.75px;border:none;color:#4682B4;background-color:#4682B4;" />
#
# - **Cleaning:** Filled missing values with the median and removed duplicates.
# - **New Features:** Added five extra columns, including a Digital Balance Score, to better capture digital habits.
# - **Filtering:** Removed unrealistic values in sleep and screen time to keep the data reliable.
#
# **Current Dataset:** 50,000 rows and 18 columns
